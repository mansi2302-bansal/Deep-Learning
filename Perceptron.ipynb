# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/placement.csv")

# %%
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
from sklearn.linear_model import Perceptron

# %%
p =Perceptron()

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
p.fit(X,y)
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[ 40.26, -36.  ]])

# %%
p.intercept_
# Out:
# array([-25.])

# %%
# so eqn is basically
# y = 40.26(X1) + (-36)X2 - 25

# %%
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
## We pass into perceptron the row vectors one by one
## z = w1(8.14) + w2(6.52) + b
## Now we have the z value , applying the activation function
## perceptron uses the step function y = step(z,0)

# %%
## initializing the weights as 0
## z = 0
## y_pred = step(z) = 1
## y_actual as given in the data is also 1
## so error = 0
## moving to the next row

# %%
## y_pred = 1
## but actual y = 0
## error = y_actual - y_pred = -1
## w_new = w_old + n(error)x
w1_new = 0 + 0.1*(-1)*6.17
w1_new
# Out:
# -0.617

# %%
w2_new = 0 + 0.1*(-1)*5.17
w2_new
# Out:
# -0.517

# %%
b_new = 0 + 0.1*(-1)
b_new
# Out:
# -0.1

# %%
z = w1_new*6.17 + w2_new*5.17 + b_new
z
# Out:
# -6.5797799999999995

# %%
## now z<0 => y_pred = 0
## now moving onto the next row with same weights

# %%
## thats how iterations keep on going

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X.values, y.values, clf=p, legend=2)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >
